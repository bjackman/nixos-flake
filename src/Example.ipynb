# %%
import argparse
import pathlib

import falba
import falba.model

# %%
db = falba.read_db(pathlib.Path("../results"))

# %%
df = db.flat_df()
experiment_metric = "fio_randread_read_clat_ns_mean"
df = df[df["metric"] == experiment_metric]

# %%
df
# Out:
#                            result_id             test_name  \
# 0  nixos-asi-benchmarks:c32f41c4bd29  nixos-asi-benchmarks
# 1  nixos-asi-benchmarks:5bfc8c9ff2a4  nixos-asi-benchmarks
# 2  nixos-asi-benchmarks:d6b0e7e4b7b4  nixos-asi-benchmarks
# 3  nixos-asi-benchmarks:12b096b6e1c1  nixos-asi-benchmarks
# 4  nixos-asi-benchmarks:7c38303a18b3  nixos-asi-benchmarks
# 5  nixos-asi-benchmarks:e1632098b358  nixos-asi-benchmarks
# 6  nixos-asi-benchmarks:a891290b0811  nixos-asi-benchmarks
# 7  nixos-asi-benchmarks:46c017d0a3da  nixos-asi-benchmarks
# 8  nixos-asi-benchmarks:b75a8a557505  nixos-asi-benchmarks
#
#                            metric         value  unit  \
# 0  fio_randread_read_clat_ns_mean  55483.539917  None
# 1  fio_randread_read_clat_ns_mean  55634.592224  None
# 2  fio_randread_read_clat_ns_mean  52755.286926  None
# 3  fio_randread_read_clat_ns_mean  74014.303040  None
# 4  fio_randread_read_clat_ns_mean  52879.843506  None
# 5  fio_randread_read_clat_ns_mean  55607.968567  None
# 6  fio_randread_read_clat_ns_mean  55356.063599  None
# 7  fio_randread_read_clat_ns_mean  55307.243530  None
# 8  fio_randread_read_clat_ns_mean  55893.367126  None
#
#           os_release_variant_id              nixos_configuration_revision
# 0  aethelred-asi-page-cache-fix  f1034e1fd7e67e1a4297386446a1339727abf647
# 1              aethelred-asi-on  0feb5d9c4330b06c4c24158bc6c8e91d654f4857
# 2             aethelred-asi-off  f1034e1fd7e67e1a4297386446a1339727abf647
# 3             aethelred-asi-off  e577f29ecdf734a2e6f59e7294b50b3a881855b9
# 4             aethelred-asi-off  0feb5d9c4330b06c4c24158bc6c8e91d654f4857
# 5              aethelred-asi-on  e577f29ecdf734a2e6f59e7294b50b3a881855b9
# 6              aethelred-asi-on  f1034e1fd7e67e1a4297386446a1339727abf647
# 7  aethelred-asi-page-cache-fix  e577f29ecdf734a2e6f59e7294b50b3a881855b9
# 8  aethelred-asi-page-cache-fix  0feb5d9c4330b06c4c24158bc6c8e91d654f4857
